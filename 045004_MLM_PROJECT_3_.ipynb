# %% [markdown]
# **PROJECT :** **E-COMMERCE CUSTOMER ANALYSIS (PROJECT 3)**
#
# **SUBMITTED BY - ADITYA SINGH YADAV**

# %% [markdown]
# ### Objective
#
# - Apply the decision tree algorithm to predict e- commerce customer segments derived from clustering. Evaluate decision tree performance using k-fold cross-validation.
# - Implement the random forest algorithm to enhance prediction accuracy compared to the decision tree. Assess random forest performance in terms of accuracy and computational resources.
# - Apply XGBoost algorithm to further improve prediction accuracy as an ensemble learning technique. Compare XGBoost performance with decision tree and random forest models.
# - Evaluate decision tree, random forest, and XGBoost models based on metrics like accuracy, precision, recall, F1-score, execution time, and memory usage to determine the most suitable model for customer segmentation and prediction.

# %% [markdown]
# **DATA DESCRIPTION**
#
# **Dataset Shape - (59998, 8)**
#
# **Dataset Size - 5 mb**
#
# **Source - Kaggle(https://www.kaggle.com/code/tyatsenk/k-means-e-commerce-customer#3.-Data-Preprocessing)**
#
#
#
#
#
#
# **DATA BIFURCATION**
#
# **Categorical Variables:**
#
# Nominal Categories:
#
# 1.Country
#
# 2.StockCode
#
# **Ordinal Categories:**
#
# 1.InvoiceDate
#
# **Non-Categorical Variables:**
#
# 1.Quantity
#
# 2.UnitPrice
#
# **Descriptive Statistics: Categorical Variables**
#
# **Count | Frequency Statistics**
#
# 1. InvoiceNo:
#
# Count: 59998
#
# Frequency: 675
#
# 2. StockCode:
#
# Count: 59998
#
# Frequency: 335
#
# 3. Country:
#
# Count: 59998
#
# Frequency: 56112
#
# **Descriptive Statistics: Non-Categorical Variables**
#
# **Measures of Central Tendency**
#
# 1. Quantity:
#
# Mean: 8.502967
#
# Median: 2.000000
#
# 2. UnitPrice:
#
# Mean: 5.989186
#
# Median: 2.510000
#
# **Measures of Dispersion**
#
# 1. Quantity:
#
# Standard Deviation: 56.746866
#
# 2. UnitPrice:
#
# Standard Deviation: 152.109427
#
# **DATA PREPROCESSING**
#
# **MISSING DATA STATISTICS AND TREATMENT**
#
# **Missing Data Statistics: Categorical Variables or Features**
#
# 1. Description: 161 missing values
#
# 2. CustomerID: 21949 missing values
#
# 3. CustomerID column has the highest proportion of missing values, accounting for approximately 36.58% of the total rows. Hence, no outliers were removed as missing data was less than 50%

# %% [markdown]
# ### Encoding and Standardization
# - Pandas Inferior Encoding method is used to encode categorical variables.
# - Standardization is used to scale non-categorical dataset

# %% [markdown]
# ### Preparing Data for Supervised Learning Models
#
# 1) Data has been merged with cluster labels to create a unified dataset for supervised learning.
# 2) Dropped non-significant columns from the dataset to streamline the feature set.
# 3) Defined the feature matrix X to include all significant independent columns and the target variable Y to represent the 'cluster' labels.
# 4) Utilized the train_test_split function with stratified random sampling to split the data into training and testing sets.

# %% [markdown]
# ### K- Means Clustring Report
# - the analysis suggests that the 3-cluster model might be the most appropriate choice, indicating better cluster quality and separation.
# - Cluster's characteristics are divided into 3 parts.
# 1. Low Users
# - Customers in this cluster may have below-average quantities of purchases and may prefer lower-priced items.
# - These customers could represent occasional or budget-conscious shoppers who make small purchases infrequently.
# 2. Medium Users
# - Customers in this cluster may exhibit moderate quantities of purchases and may show a balance between lower and higher-priced items.
# - These customers may represent a mainstream segment of regular online shoppers who make average-sized purchases at reasonable prices.
# 3. High Users
# - Customers in this cluster may have above-average quantities of purchases and may prefer higher-priced items.
# - These customers could represent frequent and high-value shoppers who make large purchases of premium products, indicating strong engagement and potentially higher loyalty.

# %% [markdown]
# ### Supervised Learning Model Reports

# %% [markdown]
# ### Decision Tree (Base Model)
# 1. Precision:
# - Class 0: 0.72
# - Class 1: 0.56
# - Class 2: 0.70
# - Class 3: 0.63
# - Class 4: 0.54
# 2. Recall:
# - Class 0: 0.72
# - Class 1: 0.56
# - Class 2: 0.70
# - Class 3: 0.62
# - Class 4: 0.56
# 3. F1-score:
# - Class 0: 0.72
# - Class 1: 0.56
# - Class 2: 0.70
# - Class 3: 0.63
# - Class 4: 0.55
# - Accuracy: 0.64 with a support of 18000.
# - Macro average precision: 0.63, recall: 0.63, F1-score: 0.63, support: 18000.
# - Weighted average precision: 0.64, recall: 0.64, F1-score: 0.64, support: 18000
# - Mean cross-validation score: 30.6%
# - Execution time: 0.5267491340637207 seconds
# - Peak memory usage: 45.01171875 MB

# %% [markdown]
# ### Random Forest
# - Precision: 0.73 for class 0, 0.60 for class 1, 0.72 for class 2, 0.64 for class 3, and 0.64 for class 4.
# - Recall: 0.75 for class 0, 0.59 for class 1, 0.70 for class 2, 0.70 for class 3, and 0.55 for class 4.
# - F1-score: 0.74 for class 0, 0.60 for class 1, 0.71 for class 2, 0.67 for class 3, and 0.59 for class 4.
# - Accuracy: 0.67
# - Macro average precision: 0.67
# - Macro average recall: 0.66
# - Macro average F1-score: 0.66
# - Weighted average precision: 0.67
# - Weighted average recall: 0.67
# - Weighted average F1-score: 0.67
# - Execution time: 7.078993082046509 seconds
# - Peak memory usage: 390.02734375 MB

# %% [markdown]
# ### XGBoost
# 1. Precision:
# - Class 0: 0.73
# - Class 1: 0.60
# - Class 2: 0.72
# - Class 3: 0.64
# - Class 4: 0.64
# 2. Recall:
# - Class 0: 0.75
# - Class 1: 0.59
# - Class 2: 0.70
# - Class 3: 0.70
# - Class 4: 0.55
# 3. F1-score:
# - Class 0: 0.74
# - Class 1: 0.60
# - Class 2: 0.71
# - Class 3: 0.67
# - Class 4: 0.59
# - Accuracy: 0.67
# - Macro average precision: 0.67
# - Macro average recall: 0.66
# - Macro average F1-score: 0.66
# - Weighted average precision: 0.67
# - Weighted average recall: 0.67
# - Weighted average F1-score: 0.67
# - Execution time: 1.8275856971740723 seconds
# - Peak memory usage: 410.94921875 MB

# %% [markdown]
# ### Comparing Decision Tree and Random Forest
# - Decision Tree (Base Model) and Random Forest both achieved comparable accuracy, around 64% and 67% respectively.
# - Random Forest generally outperforms the Decision Tree (Base Model) in terms of precision for all classes. For example, for class 0, Random Forest achieved a precision of 0.73 compared to 0.72 for the Decision Tree.
# - In terms of recall, both models exhibit similar performance across most classes, although Random Forest has slightly higher recall for class 0 and class 3.
# - Both models have similar macro average precision, recall, and F1-score, indicating overall balanced performance across all classes.
# - Random Forest demonstrates higher execution time and peak memory usage compared to the Decision Tree (Base Model). While the Decision Tree model executes in around 0.53 seconds and uses approximately 45 MB of memory, the Random Forest model takes significantly longer, approximately 7.08 seconds, and requires more memory, about 390 MB.
# - In summary, although Random Forest exhibits slightly better precision and comparable performance in other metrics, its significantly higher execution time and memory usage should be considered when choosing between the two models. Depending on the specific requirements of the application, such as the need for speed and resource constraints, the Decision Tree (Base Model) might be preferred for its faster execution and lower memory footprint.

# %% [markdown]
# ### Comparing Decision Tree and XGBOOST
# - XGBoost and Decision Tree (Base Model) achieved similar accuracy, around 67% and 64% respectively.
# - XGBoost generally outperforms the Decision Tree (Base Model) in terms of precision for all classes. For example, for class 0, XGBoost achieved a precision of 0.73 compared to 0.72 for the Decision Tree.
# - In terms of recall, both models exhibit similar performance across most classes, although XGBoost has slightly higher recall for class 3.
# - Both models have similar macro average precision, recall, and F1-score, indicating overall balanced performance across all classes.
# - XGBoost demonstrates higher execution time and peak memory usage compared to the Decision Tree (Base Model). While XGBoost executes in around 1.83 seconds and uses approximately 410 MB of memory, the Decision Tree model takes significantly less time and memory.
# - In summary, although XGBoost exhibits slightly better precision and comparable performance in other metrics, its significantly higher execution time and memory usage should be considered when choosing between the two models. Depending on the specific requirements of the application, such as the need for speed and resource constraints, the Decision Tree (Base Model) might be preferred for its faster execution and lower memory footprint.

# %% [markdown]
# ### Managerial Implications
# 1. Model Selection: Based on the provided metrics, XGBoost and Random Forest outperform the Decision Tree (Base Model) in terms of accuracy, precision, recall, and F1-score. Therefore, for tasks prioritizing predictive accuracy, considering XGBoost or Random Forest models would be advantageous.
# 2. Resource Utilization: While XGBoost and Random Forest demonstrate superior performance, they also require significantly higher execution time and memory usage compared to the Decision Tree (Base Model). Depending on available computational resources and time constraints, stakeholders should weigh the trade-offs between model performance and resource utilization.
# 3. Model Interpretability: Decision Tree models offer inherent interpretability due to their tree-like structure, making them suitable for scenarios where understanding the underlying decision-making process is critical. However, XGBoost and Random Forest models, while providing better predictive accuracy, may sacrifice interpretability due to their complex ensemble nature.
# 4. Continuous Improvement: Regular monitoring and evaluation of model performance are essential for identifying opportunities for improvement and fine-tuning hyperparameters. Additionally, exploring ensemble techniques or model stacking methods could further enhance predictive accuracy while mitigating the risk of overfitting.
# 5. Decision Support: The choice of model should align with the specific objectives and constraints of the business problem at hand. Stakeholders should consider factors such as the importance of accuracy, interpretability, computational resources, and the need for real-time predictions when selecting the most appropriate model for deployment.
# 6. Integration of Machine Learning into Business Processes:
# The analysis underscores the potential advantages of integrating machine learning models into business processes for customer segmentation and prediction. By harnessing advanced analytics techniques, organizations can extract valuable insights into customer behavior, preferences, and churn likelihood. These insights empower businesses to implement targeted marketing strategies and proactive churn management initiatives, thereby enhancing customer satisfaction and loyalty while optimizing operational efficiency.

# %% [markdown]
# ### References
# 1. Prof. Amarnath
# 2. ChatGPT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets

# %%
df = pd.read_csv('E-commerce-Data-updated_1.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (59998, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# InvoiceNo          0
# StockCode          0
# Description      161
# Quantity           0
# InvoiceDate        0
# UnitPrice          0
# CustomerID     21949
# Country            0
# dtype: int64

# %%
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# 7196     2
# 1971     2
# 45394    2
# 52262    2
# 39369    2
# dtype: int64

# %%
# Data Bifurcation
df_cat = df[[ 'Country','StockCode','InvoiceDate']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['Quantity', 'UnitPrice']] # Non-Categorical Data

# %%
nan_counts_per_column = df.isnull().sum()

# Calculate the total number of rows
total_rows = len(df)

# Calculate the percentage of missing data in each column
percentage_missing_per_column = (nan_counts_per_column / total_rows) * 100

# Display the percentage of missing data in each column
print(percentage_missing_per_column)
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268342
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     36.582886
# Country         0.000000
# dtype: float64

# %%
si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59998 entries, 0 to 59997
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      59998 non-null  object
#  1   StockCode    59998 non-null  object
#  2   InvoiceDate  59998 non-null  object
# dtypes: object(3)
# memory usage: 1.4+ MB

# %%
si_noncat = SimpleImputer(missing_values=np.nan, strategy='mean') # Other Strategy : mean | median | most_frequent | constant
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si # Missing Non-Categorical Data Imputed Subset using Simple Imputer
df_noncat_mdi_si.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59998 entries, 0 to 59997
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Quantity   59998 non-null  float64
#  1   UnitPrice  59998 non-null  float64
# dtypes: float64(2)
# memory usage: 937.6 KB

# %%
# Dataset Used : df_cat_mdi
df_cat_mdi_code = df_cat_mdi.copy()

# %%
# Using Pandas (Inferior)
df_cat_mdi_code_pd = df_cat_mdi_code.astype('category')
df_cat_mdi_code_pd['Country_code'] = df_cat_mdi_code_pd['Country'].cat.codes
df_cat_mdi_code_pd['StockCode_code'] = df_cat_mdi_code_pd['StockCode'].cat.codes
df_cat_mdi_code_pd['InvoiceDate_code'] = df_cat_mdi_code_pd['InvoiceDate'].cat.codes
df_cat_mdi_code_pd # (Missing Data Treated) Numeric Coded Categorical Dataset using Pandas
# Out:
#               Country StockCode      InvoiceDate  Country_code  \
# 0      United Kingdom    85123A   12/1/2010 8:26            23
# 1      United Kingdom     71053   12/1/2010 8:26            23
# 2      United Kingdom    84406B   12/1/2010 8:26            23
# 3      United Kingdom    84029G   12/1/2010 8:26            23
# 4      United Kingdom    84029E   12/1/2010 8:26            23
# ...               ...       ...              ...           ...
# 59993  United Kingdom     21027  1/17/2011 17:44            23
# 59994  United Kingdom     21033  1/17/2011 17:44            23
# 59995  United Kingdom     21041  1/17/2011 17:44            23
# 59996  United Kingdom     21043  1/17/2011 17:44            23
# 59997  United Kingdom     21051  1/17/2011 17:44            23
#
#        StockCode_code  InvoiceDate_code
# 0                2538               767
# 1                1995               767
# 2                2170               767
# 3                2128               767
# 4                2127               767
# ...               ...               ...
# 59993             282               364
# 59994             287               364
# 59995             293               364
# 59996             295               364
# 59997             296               364
#
# [59998 rows x 6 columns]

# %%
# Using Pandas (Inferior)
df_cat_mdi_code_pd = df_cat_mdi_code.astype('category')
df_cat_mdi_code_pd['Country_code'] = df_cat_mdi_code_pd['Country'].cat.codes
df_cat_mdi_code_pd['StockCode_code'] = df_cat_mdi_code_pd['StockCode'].cat.codes
df_cat_mdi_code_pd['InvoiceDate_code'] = df_cat_mdi_code_pd['InvoiceDate'].cat.codes

# Keep only encoded columns
encoded_columns = ['Country_code', 'StockCode_code', 'InvoiceDate_code']
df_encoded_only = df_cat_mdi_code_pd[encoded_columns]

print(df_encoded_only)
# Out:
#        Country_code  StockCode_code  InvoiceDate_code
# 0                23            2538               767
# 1                23            1995               767
# 2                23            2170               767
# 3                23            2128               767
# 4                23            2127               767
# ...             ...             ...               ...
# 59993            23             282               364
# 59994            23             287               364
# 59995            23             293               364
# 59996            23             295               364
# 59997            23             296               364
#
# [59998 rows x 3 columns]

# %%
# 3.1. Standardization
ss_quantity = StandardScaler()  # StandardScaler for Quantity
ss_unit_price = StandardScaler()  # StandardScaler for UnitPrice

ss_fit_quantity = ss_quantity.fit_transform(df_noncat_mdi_si[['Quantity']])  # Fitting and transforming Quantity
ss_fit_unit_price = ss_unit_price.fit_transform(df_noncat_mdi_si[['UnitPrice']])  # Fitting and transforming UnitPrice

# Creating DataFrame for standardized data
df_quantity_std = pd.DataFrame(ss_fit_quantity, columns=['Quantity_std'])
df_unit_price_std = pd.DataFrame(ss_fit_unit_price, columns=['UnitPrice_std'])

# Joining standardized data with the original DataFrame
df_noncat_mdt_std = df_noncat_mdi_si.join([df_quantity_std, df_unit_price_std])
df_noncat_mdt_std
# Out:
#        Quantity  UnitPrice  Quantity_std  UnitPrice_std
# 0           6.0       2.55     -0.044108      -0.022610
# 1           6.0       3.39     -0.044108      -0.017088
# 2           8.0       2.75     -0.008863      -0.021295
# 3           6.0       3.39     -0.044108      -0.017088
# 4           6.0       3.39     -0.044108      -0.017088
# ...         ...        ...           ...            ...
# 59993       1.0       0.83     -0.132219      -0.033918
# 59994      17.0       2.46      0.149737      -0.023202
# 59995       1.0       5.79     -0.132219      -0.001310
# 59996       2.0       4.13     -0.114597      -0.012223
# 59997       3.0       1.63     -0.096975      -0.028658
#
# [59998 rows x 4 columns]

# %%
# 3.1. Standardization
ss_quantity = StandardScaler()  # StandardScaler for Quantity
ss_unit_price = StandardScaler()  # StandardScaler for UnitPrice

ss_fit_quantity = ss_quantity.fit_transform(df_noncat_mdi_si[['Quantity']])  # Fitting and transforming Quantity
ss_fit_unit_price = ss_unit_price.fit_transform(df_noncat_mdi_si[['UnitPrice']])  # Fitting and transforming UnitPrice

# Creating DataFrame for standardized data
df_quantity_std = pd.DataFrame(ss_fit_quantity, columns=['Quantity_std'])
df_unit_price_std = pd.DataFrame(ss_fit_unit_price, columns=['UnitPrice_std'])

# Joining standardized data with the original DataFrame
df_noncat_mdt_std = pd.concat([df_quantity_std, df_unit_price_std], axis=1)  # Concatenating standardized columns

# Dropping original columns from df_noncat_mdi_si
df_noncat_mdi_si.drop(['Quantity', 'UnitPrice'], axis=1, inplace=True)

# Checking the resulting DataFrame
print(df_noncat_mdt_std)
# Out:
#        Quantity_std  UnitPrice_std
# 0         -0.044108      -0.022610
# 1         -0.044108      -0.017088
# 2         -0.008863      -0.021295
# 3         -0.044108      -0.017088
# 4         -0.044108      -0.017088
# ...             ...            ...
# 59993     -0.132219      -0.033918
# 59994      0.149737      -0.023202
# 59995     -0.132219      -0.001310
# 59996     -0.114597      -0.012223
# 59997     -0.096975      -0.028658
#
# [59998 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Creating box plots for standardized columns
df_noncat_mdt_std.boxplot(figsize=(10, 6))
plt.title('Box Plot of Standardized Columns')
plt.ylabel('Standardized Values')
plt.xlabel('Columns')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.grid(True)
plt.show()

# %%
df_kmeans=merged_df.copy()

# %%
from sklearn.cluster import KMeans
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3)

# %%
cluster_labels=model.fit_predict(df_kmeans)
cluster_labels
# Out:
# array([0, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
kmeans_model = KMeans(n_clusters=5, n_init=10)
kmeans_model.fit(df_kmeans)

# Get cluster labels
cluster_labels = kmeans_model.labels_

# Create DataFrame with observation index and cluster labels
cluster_df = pd.DataFrame({'observation_id': range(1, len(cluster_labels) + 1), 'cluster': cluster_labels})

# Print the DataFrame
cluster_df
# Out:
#        observation_id  cluster
# 0                   1        4
# 1                   2        4
# 2                   3        4
# 3                   4        4
# 4                   5        4
# ...               ...      ...
# 59993           59994        1
# 59994           59995        1
# 59995           59996        1
# 59996           59997        1
# 59997           59998        1
#
# [59998 rows x 2 columns]

# %%
merged_df = pd.merge(merged_df, cluster_df, left_index=True, right_on='observation_id', how='inner')

# Print the merged DataFrame
merged_df
merged_df.copy()
# Out:
#        Quantity_std  UnitPrice_std  Country_code  StockCode_code  \
# 0         -0.044108      -0.017088            23            1995
# 1         -0.008863      -0.021295            23            2170
# 2         -0.044108      -0.017088            23            2128
# 3         -0.044108      -0.017088            23            2127
# 4         -0.114597       0.010919            23            1566
# ...             ...            ...           ...             ...
# 59992     -0.132219      -0.033918            23             282
# 59993      0.149737      -0.023202            23             287
# 59994     -0.132219      -0.001310            23             293
# 59995     -0.114597      -0.012223            23             295
# 59996     -0.096975      -0.028658            23             296
#
#        InvoiceDate_code  observation_id  cluster
# 0                   767               1        4
# 1                   767               2        4
# 2                   767               3        4
# 3                   767               4        4
# 4                   767               5        4
# ...                 ...             ...      ...
# 59992               364           59993        1
# 59993               364           59994        1
# 59994               364           59995        1
# 59995               364           59996        1
# 59996               364           59997        1
#
# [59997 rows x 7 columns]

# %%
merged_df.shape
# Out:
# (59997, 7)

# %%
X_merged = merged_df.columns

# Drop the column named 'cluster' from X_merged
X_merged = X_merged.drop('cluster')
X_merged
# Out:
# Index(['Quantity_std', 'UnitPrice_std', 'Country_code', 'StockCode_code',
#        'InvoiceDate_code', 'observation_id'],
#       dtype='object')

# %%
X = merged_df[X_merged]
y = merged_df['cluster']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
dtc = DecisionTreeClassifier(criterion='gini', random_state=45004,) # Other Criteria : Entropy,  Log Loss 
dtc_model = dtc.fit(X_train,y_train); dtc_model
# Out:
# DecisionTreeClassifier(random_state=45004)

# %%
dtc_predict = dtc_model.predict(X_test); dtc_predict
# Out:
# array([2, 2, 2, ..., 4, 2, 0], dtype=int32)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,dtc_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72      4375
#            1       0.56      0.56      0.56      3085
#            2       0.70      0.70      0.70      4121
#            3       0.63      0.62      0.63      4109
#            4       0.54      0.56      0.55      2310
#
#     accuracy                           0.64     18000
#    macro avg       0.63      0.63      0.63     18000
# weighted avg       0.64      0.64      0.64     18000

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
# Perform k-fold cross-validation
k = 5  # Number of folds
scores = cross_val_score(dtc_model, X, y, cv=k)

# Print cross-validation scores for each fold
for i, score in enumerate(scores):
    print(f"Fold {i+1}: {score}")

# Calculate and print the mean cross-validation score
mean_score = scores.mean()
print(f"Mean cross-validation score: {mean_score}")
# Out:
# Fold 1: 0.42741666666666667
# Fold 2: 0.32016666666666665
# Fold 3: 0.3228602383531961
# Fold 4: 0.2757729810817568
# Fold 5: 0.1840153346112176
# Mean cross-validation score: 0.30604637747590074

# %%
#Random forest
from sklearn.ensemble import RandomForestClassifier
Rf_model= RandomForestClassifier()
Rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
Rf_pred = Rf_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,Rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74      4375
#            1       0.60      0.59      0.60      3085
#            2       0.72      0.70      0.71      4121
#            3       0.64      0.70      0.67      4109
#            4       0.64      0.55      0.59      2310
#
#     accuracy                           0.67     18000
#    macro avg       0.67      0.66      0.66     18000
# weighted avg       0.67      0.67      0.67     18000

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.0.3-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 22.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy in ./venv/lib/python3.11/site-packages (from xgboost) (1.25.0)
# Requirement already satisfied: scipy in ./venv/lib/python3.11/site-packages (from xgboost) (1.13.0)
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
#XGboost
from xgboost.sklearn import XGBClassifier
Xgb_model = XGBClassifier()
Xgb_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
Xgb_pred = Rf_model.predict(X_test)

# %%
print(classification_report(y_test,Xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74      4375
#            1       0.60      0.59      0.60      3085
#            2       0.72      0.70      0.71      4121
#            3       0.64      0.70      0.67      4109
#            4       0.64      0.55      0.59      2310
#
#     accuracy                           0.67     18000
#    macro avg       0.67      0.66      0.66     18000
# weighted avg       0.67      0.67      0.67     18000

# %%
# Decision Tree Model
from sklearn.tree import DecisionTreeClassifier
import time
from memory_profiler import memory_usage

# Measure start time
start_time = time.time()

# Start memory profiler
mem_usage = memory_usage()

# Code snippet
dtc = DecisionTreeClassifier(criterion='gini', random_state=45051)
dtc_model = dtc.fit(X_train, y_train)
dtc_predict = dtc_model.predict(X_test)

# End memory profiler
mem_usage = memory_usage(max_usage=True)

# Measure end time
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

print("Execution time:", execution_time, "seconds")
print("Peak memory usage:", mem_usage, "MB")
# Out:
# Execution time: 0.5267491340637207 seconds
# Peak memory usage: 45.01171875 MB

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
import time
from memory_profiler import memory_usage

# Measure start time
start_time = time.time()

# Start memory profiler
mem_usage = memory_usage()

# Code snippet
Rf_model= RandomForestClassifier()
Rf_model.fit(X_train,y_train)
Rf_pred = Rf_model.predict(X_test)
# End memory profiler
mem_usage = memory_usage(max_usage=True)

# Measure end time
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

print("Execution time:", execution_time, "seconds")
print("Peak memory usage:", mem_usage, "MB")
# Out:
# Execution time: 7.078993082046509 seconds
# Peak memory usage: 390.02734375 MB

# %%
#XGboost
from xgboost.sklearn import XGBClassifier
import time
from memory_profiler import memory_usage

# Measure start time
start_time = time.time()

# Start memory profiler
mem_usage = memory_usage()

# Code snippet
Xgb_model = XGBClassifier()
Xgb_model.fit(X_train,y_train)
Xgb_pred = Rf_model.predict(X_test)

# End memory profiler
mem_usage = memory_usage(max_usage=True)

# Measure end time
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

print("Execution time:", execution_time, "seconds")
print("Peak memory usage:", mem_usage, "MB")
# Out:
# Execution time: 1.8275856971740723 seconds
# Peak memory usage: 410.94921875 MB
